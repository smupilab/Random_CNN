# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import sys
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.datasets import cifar10
import numpy as np 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.datasets import cifar10
from keras.optimizers import SGD

print('Python version : ', sys.version)
print('Keras version : ', keras.__version__)


(x_train, y_train), (x_test, y_test) = cifar10.load_data()
num_classes = 10
epochs =30

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

num_classes = 10
epochs = 30
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()

model.add(Conv2D(32, (3, 3), input_shape=x_train.shape[1:], activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

# 2차원 배열 -> 1차원 배열
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

epochs = 30
lrate = 0.01
decay = lrate/epochs
sgd = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=False)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=epochs, verbose=1, validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:',  score[0])
print('Test accuracy:', score[1])
model.save('MNIST_CNN_model.h5')
# Out:
# Python version :  3.7.10 (default, Feb 20 2021, 21:17:23)
# [GCC 7.5.0]
# Keras version :  2.4.0
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Epoch 1/30
# 1563/1563 [==============================] - 11s 7ms/step - loss: 2.1106 - accuracy: 0.2065 - val_loss: 1.5890 - val_accuracy: 0.4275
# Epoch 2/30
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.5190 - accuracy: 0.4443 - val_loss: 1.3409 - val_accuracy: 0.5138
# Epoch 3/30
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.3032 - accuracy: 0.5298 - val_loss: 1.1850 - val_accuracy: 0.5683
# Epoch 4/30
# 1563/1563 [==============================] - 10s 7ms/step - loss: 1.1529 - accuracy: 0.5841 - val_loss: 1.0490 - val_accuracy: 0.6225
# Epoch 5/30
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.0329 - accuracy: 0.6294 - val_loss: 0.9755 - val_accuracy: 0.6544
# Epoch 6/30
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.9311 - accuracy: 0.6722 - val_loss: 0.9004 - val_accuracy: 0.6798
# Epoch 7/30
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.8631 - accuracy: 0.6928 - val_loss: 0.8248 - val_accuracy: 0.7093
# Epoch 8/30
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.7917 - accuracy: 0.7178 - val_loss: 0.7996 - val_accuracy: 0.7223
# Epoch 9/30
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.7358 - accuracy: 0.7398 - val_loss: 0.7608 - val_accuracy: 0.7326
# Epoch 10/30
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.6925 - accuracy: 0.7529 - val_loss: 0.7419 - val_accuracy: 0.7381
# Epoch 11/30
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.6491 - accuracy: 0.7705 - val_loss: 0.7257 - val_accuracy: 0.7484
# Epoch 12/30
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.6152 - accuracy: 0.7826 - val_loss: 0.6949 - val_accuracy: 0.7588
# Epoch 13/30
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.5835 - accuracy: 0.7927 - val_loss: 0.6829 - val_accuracy: 0.7639
# Epoch 14/30
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.5492 - accuracy: 0.8058 - val_loss: 0.6796 - val_accuracy: 0.7665
# Epoch 15/30
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.5276 - accuracy: 0.8120 - val_loss: 0.6686 - val_accuracy: 0.7710
# Epoch 16/30
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.4994 - accuracy: 0.8221 - val_loss: 0.6595 - val_accuracy: 0.7735
# Epoch 17/30
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.4712 - accuracy: 0.8331 - val_loss: 0.6434 - val_accuracy: 0.7815
# Epoch 18/30
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.4532 - accuracy: 0.8397 - val_loss: 0.6591 - val_accuracy: 0.7785
# Epoch 19/30
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.4325 - accuracy: 0.8445 - val_loss: 0.6352 - val_accuracy: 0.7820
# Epoch 20/30
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.4151 - accuracy: 0.8525 - val_loss: 0.6572 - val_accuracy: 0.7830
# Epoch 21/30
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.4002 - accuracy: 0.8574 - val_loss: 0.6429 - val_accuracy: 0.7864
# Epoch 22/30
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.3753 - accuracy: 0.8646 - val_loss: 0.6286 - val_accuracy: 0.7912
# Epoch 23/30
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.3698 - accuracy: 0.8681 - val_loss: 0.6341 - val_accuracy: 0.7891
# Epoch 24/30
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.3484 - accuracy: 0.8744 - val_loss: 0.6568 - val_accuracy: 0.7859
# Epoch 25/30
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.3423 - accuracy: 0.8769 - val_loss: 0.6331 - val_accuracy: 0.7921
# Epoch 26/30
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.3300 - accuracy: 0.8804 - val_loss: 0.6323 - val_accuracy: 0.7950
# Epoch 27/30
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.3101 - accuracy: 0.8886 - val_loss: 0.6426 - val_accuracy: 0.7922
# Epoch 28/30
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.3085 - accuracy: 0.8900 - val_loss: 0.6525 - val_accuracy: 0.7942
# Epoch 29/30
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.2951 - accuracy: 0.8939 - val_loss: 0.6419 - val_accuracy: 0.7982
# Epoch 30/30
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.2846 - accuracy: 0.8973 - val_loss: 0.6504 - val_accuracy: 0.7986
# Test loss: 0.6504215598106384
# Test accuracy: 0.7986000180244446
